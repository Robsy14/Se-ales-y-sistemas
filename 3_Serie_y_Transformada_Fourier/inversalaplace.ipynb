# %% [markdown]
# <a href="https://colab.research.google.com/github/Robsy14/Se-ales-y-sistemas/blob/main/3_Serie_y_Transformada_Fourier/inversalaplace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ejercicio
#
# * Obtener la transformada inversa de Laplace de
#     \begin{equation}
#     X(s) = \frac{1}{(s+1)(s+2)^2} \qquad \text{for } \Re \{ s \} \geq -1
#     \end{equation}
#     manualmente. Comprobar los resultados utilizando `SymPy`.

# %% [markdown]
# import sympy as sp
#
# # Definir variables
# s, t = sp.symbols('s t')
#
# # Definir X(s)
# X_s = 1 / ((s + 1) * (s + 2)**2)
#
# # Transformada inversa de Laplace
# x_t = sp.inverse_laplace_transform(X_s, s, t)
# x_t

# %% [markdown]
# ![laplace.jpg](data:image/jpeg;base64,...)
